# %%
from bs4 import BeautifulSoup
import requests 
import pandas as pd
import re
from datetime import datetime

# %%
#입력된 수를 1, 11, 21, 31 ...만들어 주는 함수
def makePgNum(num):
    if num == 1:
        page_num1 = num
        return page_num1
    elif num == 0:
        page_num2 = num+1
        return page_num2
    else:
        page_num3 = num+9*(num-1)
        return page_num3

# %%
# 크롤링할 url 생성하는 함수 만들기(검색어, 크롤링 시작 페이지, 크롤링 종료 페이지)
def makeUrl(search,start_pg,end_pg,start_date, end_date):
    if start_pg == end_pg:
        start_page = makePgNum(start_pg)
        url = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=" + search + f'&sm=tab_opt&nso=so:r,p:from{start_date}to{end_date}'+"&start=" + str(start_page)
        print("생성url: ",url)
        return url
    else:
        urls= []
        for i in range(start_pg, end_pg+1):
            page = makePgNum(i)
            url = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=" + search + f'&sm=tab_opt&nso=so:r,p:from{start_date}to{end_date}' + "&start=" + str(page)
            urls.append(url)
        print("생성url: ",urls)
        return urls

# %%
def get_links (search_urls) :
  headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) Chrome/98.0.4758.102"}

  naver_urls = []
  press_name = []


  cnt = 0
  for i in search_urls :
      cnt =+ 1
      print("-----------> ", cnt)
      print("search_urls: ", i)
      response = requests.get(i, headers=headers)
      html = response.text
      soup = BeautifulSoup(html, "html.parser")
  
      news = soup.select("div > div.news_info > div.info_group > a ")     # a:nth-of-type(3)
      article = soup.select("a.info.press") # i당 10개
      articles = []
      for art in article:
        articles.append(art)

      #print("\n뉴스 : ",news)
      #print("\n아티클 : ", article)
      cnt = 0
      idx = 0
      
      for n in news:
        cnt += 1
        print("-- ", cnt, " : ", n)

        if "sid1=106" in n['href'] :
              pass
        elif "sports" in n['href'] :
              pass
            
        elif  n['href'].startswith("https://news.naver.com"):
              print("\n네이버뉴스 입니다")
              news_url = n['href']
              naver_urls.append(news_url)
              try:
                press_name.append(articles[idx-1].text.replace("선정",""))
              except:
                print('none')
              
              
        else:
          idx += 1
          
  return naver_urls, press_name

# %%
def get_content (naver_urls) : 
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) Chrome/98.0.4758.102"}


    titles = []
    contents = []
    news_date = []
    report = []

    for i in naver_urls :
        original_html = requests.get (i, headers=headers)
        h = original_html.content
        html = BeautifulSoup(h, "html.parser")
        title = html.select("#ct > div.media_end_head.go_trans > div.media_end_head_title > h2")
        title = ''.join(str(title)) # 문자열 합치기
        
        del_str = '<[^>]*>'
        title = re.sub(pattern=del_str, repl='',string=title)
        titles.append(title) 
        
        # 본문
        content = html.select("#dic_area")
        content = ''.join(str(content))
        content = re.sub(pattern=del_str, repl='',string=content)
        del_str2 = """[\n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}"""
        content = content.replace(del_str2,'')
        # print(contents)
        contents.append(content)
        
        # 기사작성일
        p_date = html.select("span.media_end_head_info_datestamp_time._ARTICLE_DATE_TIME")
        4
        
        if  "sid1=106" in i:
            sports = html.select("#content > div.end_ct > div > div.article_info > span > em")
            pattern1=r'([0-9]{4})-([0-9]{2})-([0-9]{2})'
            regex_result1 = re.search(pattern1, str(sports))
            pub_date1 = regex_result1.group(0)
            news_date.append(pub_date1)
                    
        else : 
            pattern=r'([0-9]{4})-([0-9]{2})-([0-9]{2})'
            regex_result = re.search(pattern, str(p_date))
            pub_date = regex_result.group(0)
            news_date.append(pub_date)
    
        # 기자이름
        
        r = html.select("#ct > div.media_end_head.go_trans > div.media_end_head_info.nv_notrans > div.media_end_head_journalist > a > em")
        if len(r) == 0:
            r = html.select("#contents > div.byline > p > span")
        report.append(r)
    
    reporters = []

    for a in report :
        if len(a) ==0 :
            reporters.append(r)
        
        else :
            b = a[0].text # 위치값 
            reporters.append(b.replace(' 기자',''))

    return titles, contents, news_date, reporters

# %%
def makeFrame (news_date, press_name, reporters, naver_urls, titles, contents):
    data = pd.DataFrame({"Pub_date" : news_date, "Press_name" : press_name, "Reporter" : reporters, "News_url" : naver_urls, "Title" : titles, "Content" : contents})
    return data

# %%
#검색어 입력
search = input("검색할 키워드를 입력해주세요:")

#검색시작일
start_date = input("검색 시작 날짜 (YYYYmmdd) : ")

#검색종료일
end_date = input("검색 종료 날짜 (YYYYmmdd) : ")

#검색 시작할 페이지 입력
page = int(input("\n크롤링할 시작 페이지를 입력해주세요. ex)1(숫자만입력):"))
print("\n크롤링할 시작 페이지: ",page,"페이지")   
#검색 종료할 페이지 입력
page2 = int(input("\n크롤링할 종료 페이지를 입력해주세요. ex)1(숫자만입력):"))
print("\n크롤링할 종료 페이지: ",page2,"페이지")   

# naver url 생성
search_urls = makeUrl(search,page, page2,start_date, end_date)
naver_urls, press_name = get_links (search_urls)
titles, contents, news_date, reporters = get_content (naver_urls)
data = makeFrame (news_date, press_name, reporters, naver_urls, titles, contents)
# Out:
# 크롤링할 시작 페이지:  1 페이지
#
# 크롤링할 종료 페이지:  500 페이지
# 생성url:  ['https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=1', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=11', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=21', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=31', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=41', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=51', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=61', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=71', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=81', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=91', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=101', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=111', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=121', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=131', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=141', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=151', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=161', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=171', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=181', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=191', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=201', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=211', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=221', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=231', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=241', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=251', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=261', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=271', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=281', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=291', 'https://sea ...
# ----------->  1
# search_urls:  https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=1
# --  1  :  <a class="info press" href="https://byline.network" onclick="return goOtherCR(this, 'a=nws*b.prof&amp;r=1&amp;i=8818981e_000000000000000000001562&amp;g=5704.0000001562&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fbyline.network%2Fwp-content%2Fuploads%2F2018%2F10%2Fcropped-icon-192x192.png&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>바이라인네트워크</a>
# --  2  :  <a class="info press" href="http://www.hankookilbo.com/" onclick="return goOtherCR(this, 'a=nws*e.prof&amp;r=4&amp;i=88156f75_000000000000000000452158&amp;g=469.0000452158&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fmimgnews.pstatic.net%2Fimage%2Fupload%2Foffice_logo%2F469%2F2017%2F01%2F05%2Flogo_469_18_20170105111205.png&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>한국일보</a>
# --  3  :  <a class="info" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=sec&amp;sid1=105&amp;oid=469&amp;aid=0000452158" onclick="return goOtherCR(this, 'a=nws*e.nav&amp;r=4&amp;i=88156f75_000000000000000000452158&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a>
#
# 네이버뉴스 입니다
# --  4  :  <a class="info press" href="http://www.medicalworldnews.co.kr" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=5&amp;i=881843a9_000000000000000000007819&amp;g=5620.0000007819&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Fmedicalworldnews.co.kr%2Fdata%2Ffile%2Flogo%2F3554371113_NDOVvERj_EBA994EB9494ECBBACEC9B94EB939CEB89B4EC8AA4_ED8C8CEBB984ECBD98.png&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>메디컬월드뉴스</a>
# --  5  :  <a class="info press" href="http://www.thescoop.co.kr" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=6&amp;i=88155e95_000000000000000000012921&amp;g=5311.0000012921&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Fwww.thescoop.co.kr%2Fimage%2Flogo%2Ffavicon_20180405095725.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>더스쿠프</a>
# --  6  :  <a class="info press" href="http://www.busan.com/" onclick="return goOtherCR(this, 'a=nws*j.prof&amp;r=7&amp;i=880000CE_000000000000000000964965&amp;g=082.0000964965&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fmimgnews.pstatic.net%2Fimage%2Fupload%2Foffice_logo%2F082%2F2019%2F08%2F26%2Flogo_082_18_20190826164926.png&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>부산일보<i class="spnew ico_pick">언론사 선정</i></a>
# --  7  :  <a class="info" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=sec&amp;sid1=102&amp;oid=082&amp;aid=0000964965" onclick="return goOtherCR(this, 'a=nws*j.nav&amp;r=7&amp;i=880000CE_000000000000000000964965&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a>
#
# 네이버뉴스 입니다
# --  8  :  <a class="info press" href="http://www.ifm.kr" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=8&amp;i=8818b89a_000000000000000000007619&amp;g=5713.0000007619&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Fwww.ifm.kr%2Ffavicon.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>경인방송</a>
# --  9  :  <a class="info press" href="http://www.mk.co.kr/" onclick="return goOtherCR(this, 'a=nws*j.prof&amp;r=9&amp;i=880000BC_000000000000000004478972&amp;g=009.0004478972&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fmimgnews.pstatic.net%2Fimage%2Fupload%2Foffice_logo%2F009%2F2018%2F03%2F07%2Flogo_009_18_20180307164907.jpg&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>매일경제<i class="spnew ico_pick">언론사 선정</i></a>
# --  10  :  <a class="info" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=sec&amp;sid1=101&amp;oid=009&amp;aid=0004478972" onclick="return goOtherCR(this, 'a=nws*j.nav&amp;r=9&amp;i=880000BC_000000000000000004478972&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a>
#
# 네이버뉴스 입니다
# --  11  :  <a class="info press" href="http://news.appstory.co.kr/" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=10&amp;i=88193075_000000000000000000001062&amp;g=5716.0000001062&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fimg.appstory.co.kr%2Fm.appstory.co.kr%2Ficon%2F192x192.png&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span
co.kr" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=12&amp;i=8817ca72_000000000000000000044197&amp;g=5527.0000044197&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Fcdn.news2day.co.kr%2Fdata%2Fadmin%2F1911%2Fda2262dbb70a4e93c19ef8a7c15ed835_9vuo7yzXg6sAmRPFYpWYgzVo7fBbxIa6.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>뉴스투데이</a>
# ----------->  1
# search_urls:  https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=61
# --  1  :  <a class="info press" href="http://www.newspim.com" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=1&amp;i=88000394_000000000000000001315185&amp;g=5002.0001315185&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Fimg.newspim.com%2Fm%2Fmweb%2Ffavicon_144X144V2.png&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>뉴스핌</a>
# --  2  :  <a class="info press" href="http://www.dailypop.kr" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=2&amp;i=8817ca7d_000000000000000000008861&amp;g=5516.0000008861&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb bg_default_press" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="..." width="20"/></span>데일리팝</a>
# --  3  :  <a class="info press" href="https://www.foodneconomy.com/" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=3&amp;i=881830fd_000000000000000000011219&amp;g=5567.0000011219&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Fwww.iloveorganic.co.kr%2Fimage%2Flogo%2Ffavicon.png&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>푸드경제신문 organiclife</a>
# --  4  :  <a class="info press" href="http://www.datasom.co.kr" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=4&amp;i=8818b64b_000000000000000000001466&amp;g=5711.0000001466&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Fwww.datasom.co.kr%2Fimage%2Flogo%2Ffavicon_20180913094828.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>데이터솜</a>
# ...
# ----------->  1
# search_urls:  https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=4781
# --  1  :  <a class="info press" href="http://www.foodtvnews.com" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=1&amp;i=88172bff_000000000000000000035703&amp;g=5484.0000035703&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Ffetv.co.kr%2Fdata%2Fskin%2Flayout%2F1%2Fm13%2Fimages%2Ffavicon.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>FETV</a>
# ----------->  1
# search_urls:  https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=4791
# --  1  :  <a class="info press" href="http://www.foodtvnews.com" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=1&amp;i=88172bff_000000000000000000035703&amp;g=5484.0000035703&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Ffetv.co.kr%2Fdata%2Fskin%2Flayout%2F1%2Fm13%2Fimages%2Ffavicon.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>FETV</a>
# ----------->  1
# search_urls:  https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=4801
# --  1  :  <a class="info press" href="http://www.foodtvnews.com" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=1&amp;i=88172bff_000000000000000000035703&amp;g=5484.0000035703&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Ffetv.co.kr%2Fdata%2Fskin%2Flayout%2F1%2Fm13%2Fimages%2Ffavicon.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>FETV</a>
# ----------->  1
# search_urls:  https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=4811
# --  1  :  <a class="info press" href="http://www.foodtvnews.com" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=1&amp;i=88172bff_000000000000000000035703&amp;g=5484.0000035703&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Ffetv.co.kr%2Fdata%2Fskin%2Flayout%2F1%2Fm13%2Fimages%2Ffavicon.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>FETV</a>
# ----------->  1
# search_urls:  https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=4821
# --  1  :  <a class="info press" href="http://www.foodtvnews.com" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=1&amp;i=88172bff_000000000000000000035703&amp;g=5484.0000035703&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Ffetv.co.kr%2Fdata%2Fskin%2Flayout%2F1%2Fm13%2Fimages%2Ffavicon.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>FETV</a>
# ----------->  1
# search_urls:  https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=4831
# --  1  :  <a class="info press" href="http://www.foodtvnews.com" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=1&amp;i=88172bff_000000000000000000035703&amp;g=5484.0000035703&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Ffetv.co.kr%2Fdata%2Fskin%2Flayout%2F1%2Fm13%2Fimages%2Ffavicon.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>FETV</a>
# ----------->  1
# search_urls:  https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=4841
# --  1  :  <a class="info press" href="http://www.foodtvnews.com" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=1&amp;i=88172bff_000000000000000000035703&amp;g=5484.0000035703&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Ffetv.co.kr%2Fdata%2Fskin%2Flayout%2F1%2Fm13%2Fimages%2Ffavicon.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>FETV</a>
# ----------->  1
# search_urls:  https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=4851
# --  1  :  <a class="info press" href="http://www.foodtvnews.com" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=1&amp;i=88172bff_000000000000000000035703&amp;g=5484.0000035703&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Ffetv.co.kr%2Fdata%2Fskin%2Flayout%2F1%2Fm13%2Fimages%2Ffavicon.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>FETV</a>
# ----------->  1
# search_urls:  https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=4861
# --  1  :  <a class="info press" href="http://www.foodtvnews.com" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=1&amp;i=88172bff_000000000000000000035703&amp;g=5484.0000035703&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Ffetv.co.kr%2Fdata%2Fskin%2Flayout%2F1%2Fm13%2Fimages%2Ffavicon.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>FETV</a>
# ----------->  1
# search_urls:  https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=4871
# --  1  :  <a class="info press" href="http://www.foodtvnews.com" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=1&amp;i=88172bff_000000000000000000035703&amp;g=5484.0000035703&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Ffetv.co.kr%2Fdata%2Fskin%2Flayout%2F1%2Fm13%2Fimages%2Ffavicon.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>FETV</a>
# ----------->  1
# search_urls:  https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=4881
# --  1  :  <a class="info press" href="http://www.foodtvnews.com" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=1&amp;i=88172bff_000000000000000000035703&amp;g=5484.0000035703&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Ffetv.co.kr%2Fdata%2Fskin%2Flayout%2F1%2Fm13%2Fimages%2Ffavicon.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>FETV</a>
# ----------->  1
# search_urls:  https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=4891
# --  1  :  <a class="info press" href="http://www.foodtvnews.com" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=1&amp;i=88172bff_000000000000000000035703&amp;g=5484.0000035703&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Ffetv.co.kr%2Fdata%2Fskin%2Flayout%2F1%2Fm13%2Fimages%2Ffavicon.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>FETV</a>
# ----------->  1
# search_urls:  https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=4901
# --  1  :  <a class="info press" href="http://www.foodtvnews.com" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=1&amp;i=88172bff_000000000000000000035703&amp;g=5484.0000035703&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Ffetv.co.kr%2Fdata%2Fskin%2Flayout%2F1%2Fm13%2Fimages%2Ffavicon.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>FETV</a>
# ----------->  1
# search_urls:  https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=4911
# --  1  :  <a class="info press" href="http://www.foodtvnews.com" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=1&amp;i=88172bff_000000000000000000035703&amp;g=5484.0000035703&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Ffetv.co.kr%2Fdata%2Fskin%2Flayout%2F1%2Fm13%2Fimages%2Ffavicon.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>FETV</a>
# ----------->  1
# search_urls:  https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=4921
# --  1  :  <a class="info press" href="http://www.foodtvnews.com" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=1&amp;i=88172bff_000000000000000000035703&amp;g=5484.0000035703&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Ffetv.co.kr%2Fdata%2Fskin%2Flayout%2F1%2Fm13%2Fimages%2Ffavicon.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>FETV</a>
# ----------->  1
# search_urls:  https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=4931
# --  1  :  <a class="info press" href="http://www.foodtvnews.com" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=1&amp;i=88172bff_000000000000000000035703&amp;g=5484.0000035703&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Ffetv.co.kr%2Fdata%2Fskin%2Flayout%2F1%2Fm13%2Fimages%2Ffavicon.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>FETV</a>
# ----------->  1
# search_urls:  https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=4941
# --  1  :  <a class="info press" href="http://www.foodtvnews.com" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=1&amp;i=88172bff_000000000000000000035703&amp;g=5484.0000035703&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Ffetv.co.kr%2Fdata%2Fskin%2Flayout%2F1%2Fm13%2Fimages%2Ffavicon.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>FETV</a>
# ----------->  1
# search_urls:  https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=4951
# --  1  :  <a class="info press" href="http://www.foodtvnews.com" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=1&amp;i=88172bff_000000000000000000035703&amp;g=5484.0000035703&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Ffetv.co.kr%2Fdata%2Fskin%2Flayout%2F1%2Fm13%2Fimages%2Ffavicon.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>FETV</a>
# ----------->  1
# search_urls:  https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=4961
# --  1  :  <a class="info press" href="http://www.foodtvnews.com" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=1&amp;i=88172bff_000000000000000000035703&amp;g=5484.0000035703&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Ffetv.co.kr%2Fdata%2Fskin%2Flayout%2F1%2Fm13%2Fimages%2Ffavicon.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>FETV</a>
# ----------->  1
# search_urls:  https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=4971
# --  1  :  <a class="info press" href="http://www.foodtvnews.com" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=1&amp;i=88172bff_000000000000000000035703&amp;g=5484.0000035703&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Ffetv.co.kr%2Fdata%2Fskin%2Flayout%2F1%2Fm13%2Fimages%2Ffavicon.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>FETV</a>
# ----------->  1
# search_urls:  https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=4981
# --  1  :  <a class="info press" href="http://www.foodtvnews.com" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=1&amp;i=88172bff_000000000000000000035703&amp;g=5484.0000035703&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Ffetv.co.kr%2Fdata%2Fskin%2Flayout%2F1%2Fm13%2Fimages%2Ffavicon.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>FETV</a>
# ----------->  1
# search_urls:  https://search.naver.com/search.naver?where=news&sm=tab_pge&query=전동킥보드+충전&sm=tab_opt&nso=so:r,p:from20190101to20191231&start=4991
# --  1  :  <a class="info press" href="http://www.foodtvnews.com" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=1&amp;i=88172bff_000000000000000000035703&amp;g=5484.0000035703&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Ffetv.co.kr%2Fdata%2Fskin%2Flayout%2F1%2Fm13%2Fimages%2Ffavicon.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>FETV</a>

# %%
data
# Out:
#        Pub_date Press_name                       Reporter  \
# 0    2019-12-27       한국일보                            곽주현
# 1    2019-12-10   부산일보언론사                             김성현
# 2    2019-12-09   매일경제언론사                             원호섭
# 3    2019-12-06   동아일보언론사   요코하마=김범석 특파원(bsism@donga.com)
# 4    2019-12-02        뉴스1            이헌일(honey@news1.kr)
# ..          ...        ...                            ...
# 679  2019-02-28       동아일보       세종=송충현(balgun@donga.com)
# 680  2019-03-06       매일경제                            이하연
# 681  2019-02-28       동아일보       세종=송충현(balgun@donga.com)
# 682  2019-02-06    뉴시스언론사                             박대로
# 683  2019-01-18      머니투데이    중기협력팀 오지훈(byjoon5@mt.co.kr)
#
#                                               News_url  \
# 0    https://news.naver.com/main/read.naver?mode=LS...
# 1    https://news.naver.com/main/read.naver?mode=LS...
# 2    https://news.naver.com/main/read.naver?mode=LS...
# 3    https://news.naver.com/main/read.naver?mode=LS...
# 4    https://news.naver.com/main/read.naver?mode=LS...
# ..                                                 ...
# 679  https://news.naver.com/main/read.naver?mode=LS...
# 680  https://news.naver.com/main/read.naver?mode=LS...
# 681  https://news.naver.com/main/read.naver?mode=LS...
# 682  https://news.naver.com/main/read.naver?mode=LS...
# 683  https://news.naver.com/main/read.naver?mode=LS...
#
#                                                  Title  \
# 0                    [길가에 애물단지 공유킥보드, 전용 주차장 생기고 있지만…]
# 1                   [전동 킥보드 공유 서비스 ‘라임’ 타보니…비싸고 위험하고…]
# 2                       [주유소의 재발견…"전기차 충전하고 가족 식사 할까"]
# 3                            [“차보다 편리” 日젊은층 파고든 전동휠체어]
# 4                      ["전동퀵보드 면허 만들자"…시민 제안한 규제개혁안은?]
# ..                                                 ...
# 679                            [한전 전력데이터, 민간 활용 길 열렸다]
# 680  [Defeated in four-wheel ride-sharing, Kakao la...
# 681                            [한전 전력데이터, 민간 활용 길 열렸다]
# 682                      [런던·베를린·파리도 미세먼지 골치…대책 모색 골몰]
# 683                      [젠트로피-알톤스포츠, 전기자전거 공동 개발 MOU]
#
#                                                Content
# 0    [\n일부 도로ㆍ인도에 무분별 주차 “공유서비스 인식 개선 필요”\n\n\n\n서울...
# 1    [\n\n\n\n\n지난달 부산에 본격 출시된 공유 전동 킥보드가 안전 문제와 비싼...
# 2    [\n`복합 서비스공간`으로 수익 돌파구 모색버거킹 입점 예상외 대박주말 가족손님 ...
# 3    [\n5시간 충전하면 최장 16km 주행… 노인 이동수단서 출퇴근용 진화정부도 ‘퍼...
# 4    [\n자전거 일방통행 이면도로 양방향 통행·다자녀카드 통합 등\n\n\n\n2일 서...
# ..                                                 ...
# 679  [\n정부, 2호 규제 샌드박스 5건 승인\n\n\n\nA치킨 프랜차이즈 본사는 최...
# 680  [\n\t\t\t[Pulse로 배우는 영작문-599] 'Pulse로 배우는 영작문'...
# 681  [\n정부, 2호 규제 샌드박스 5건 승인\n\n\n\nA치킨 프랜차이즈 본사는 최...
# 682  [\n런던, 나무 무료 배부…베를린, 건설기계 등급제파리, 경유차 퇴출…보르도, 전...
# 683  [\n\t\t\t[머니투데이 중기협력팀 오지훈 기자]  \n\n\n\n이재상(사진 ...
#
# [684 rows x 6 columns]

# %%
data["Title"] = data["Title"].str.replace(pat=r'[^\w]', repl=r' ', regex=True)
data["Title"] = data["Title"].str.replace("[0-9]+", repl=r" ", regex=True)
data["Title"] = data["Title"].str.replace(pat=r'[^ㄱ-ㅎㅏ-ㅣ가-힣]',repl=r" ",regex=True)

data["Content"] = data["Content"].str.replace(pat=r'(\[a-zA-Z0-9\_.+-\]+@\[a-zA-Z0-9-\]+.\[a-zA-Z0-9-.\]+)', repl=r'', regex=True)
data["Content"] = data["Content"].str.replace(pat=r'[^ㄱ-ㅎㅏ-ㅣ가-힣]',repl=r" ",regex=True)
data["Content"] = data["Content"].str.replace(pat=r'[^\w]', repl=r' ', regex=True)
data["Content"] = data["Content"].str.replace(pat=r'[\r|\n]', repl=r' ', regex=True)
data["Content"] = data["Content"].str.replace(pat=r'<[^>]*>', repl=r' ', regex=True)
data["Content"] = data["Content"].str.replace("[0-9]+", repl=r" ", regex=True)

data['Reporter'] = data['Reporter'].str.replace(pat=r'[^ㄱ-ㅎㅏ-ㅣ가-힣]',repl=r" ",regex=True)

# %%
data.isnull().sum()
# Out:
# Pub_date       0
# Press_name     0
# Reporter      46
# News_url       0
# Title          0
# Content        0
# dtype: int64

# %%
data = data.fillna("기타")

# %%
# 중복 확인 후 제거
final_df = data.copy()
dup = final_df.duplicated(['News_url']).sum()
print(dup)
final_df=final_df.drop_duplicates(['News_url'])
# Out:
# 255

# %%
final_df
# Out:
#        Pub_date Press_name                       Reporter  \
# 0    2019-12-27       한국일보                            곽주현
# 1    2019-12-10   부산일보언론사                             김성현
# 2    2019-12-09   매일경제언론사                             원호섭
# 3    2019-12-06   동아일보언론사   요코하마 김범석 특파원
# 4    2019-12-02        뉴스1            이헌일
# ..          ...        ...                            ...
# 677  2019-02-27      머니투데이       세종 권혜민
# 678  2019-03-06       매일경제                            이하연
# 679  2019-02-28       동아일보       세종 송충현
# 682  2019-02-06    뉴시스언론사                             박대로
# 683  2019-01-18      머니투데이    중기협력팀 오지훈
#
#                                               News_url  \
# 0    https://news.naver.com/main/read.naver?mode=LS...
# 1    https://news.naver.com/main/read.naver?mode=LS...
# 2    https://news.naver.com/main/read.naver?mode=LS...
# 3    https://news.naver.com/main/read.naver?mode=LS...
# 4    https://news.naver.com/main/read.naver?mode=LS...
# ..                                                 ...
# 677  https://news.naver.com/main/read.naver?mode=LS...
# 678  https://news.naver.com/main/read.naver?mode=LS...
# 679  https://news.naver.com/main/read.naver?mode=LS...
# 682  https://news.naver.com/main/read.naver?mode=LS...
# 683  https://news.naver.com/main/read.naver?mode=LS...
#
#                                                  Title  \
# 0                     길가에 애물단지 공유킥보드  전용 주차장 생기고 있지만
# 1                    전동 킥보드 공유 서비스  라임  타보니 비싸고 위험하고
# 2                        주유소의 재발견  전기차 충전하고 가족 식사 할까
# 3                              차보다 편리   젊은층 파고든 전동휠체어
# 4                        전동퀵보드 면허 만들자  시민 제안한 규제개혁안은
# ..                                                 ...
# 677                  규제 샌드박스   호 한전 전력데이터 민간 활용 가능해진다
# 678                                                ...
# 679                             한전 전력데이터  민간 활용 길 열렸다
# 682                       런던 베를린 파리도 미세먼지 골치 대책 모색 골몰
# 683                       젠트로피 알톤스포츠  전기자전거 공동 개발
#
#                                                Content
# 0      일부 도로 인도에 무분별 주차  공유서비스 인식 개선 필요     서울 마포구 ...
# 1          지난달 부산에 본격 출시된 공유 전동 킥보드가 안전 문제와 비싼 요금으로...
# 2       복합 서비스공간 으로 수익 돌파구 모색버거킹 입점 예상외 대박주말 가족손님  ...
# 3       시간 충전하면 최장      주행  노인 이동수단서 출퇴근용 진화정부도  퍼스...
# 4      자전거 일방통행 이면도로 양방향 통행 다자녀카드 통합 등     일 서울 중구 ...
# ..                                                 ...
# 677        머니투데이 세종 권혜민 기자   제 차 산업융합 규제특례심의회 개최 나머...
# 678             로 배우는 영작문            로 배우는 영작문 으로 영...
# 679    정부   호 규제 샌드박스  건 승인     치킨 프랜차이즈 본사는 최근 경기도...
# 682    런던  나무 무료 배부 베를린  건설기계 등급제파리  경유차 퇴출 보르도  전기...
# 683        머니투데이 중기협력팀 오지훈 기자       이재상 사진 가운데   주승...
#
# [429 rows x 6 columns]

# %%
# csv 저장
import datetime

now = datetime.datetime.now()
filename = "{}".format(search) + "_" + "{}".format(end_date)
df = final_df.to_csv(filename +'.csv', encoding = "utf-8-sig", index = False)
