# %% [markdown]
# # 라이브러리&데이터 불러오기

# %%
import pandas as pd
import numpy as np

# 그래프 관련 라이브러리
import matplotlib.pyplot as plt
import seaborn as sns
import platform
from matplotlib.pyplot import style

# 스타일 설정
style.use('seaborn')

# 한글 폰트 설정
if (platform.system() == 'Windows'):
    plt.rc('font', family='Malgun Gothic')
else:
    plt.rc('font', family='AppleGothic')

# 음수(-)가 깨지는 현상 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_excel('cleand raw.xlsx')

# %%
pd.set_option('display.max_columns', 21)
df.head(5)
# Out:
#     구분  아이디or이메일              진단일자     회차    악궁구조  나이  성별    키  몸무게 양치시간 비뚠니  \
# 0  비회원         0  2022-05-02 10:19  1 / 1  보통구강구조  22  남성  0cm  0kg   2분   n
# 1  비회원         0  2022-05-02 10:06  1 / 1  보통구강구조  22  남성  0cm  0kg   2분   n
# 2  비회원         0  2022-05-02 09:16  1 / 1  보통구강구조  33  여성  0cm  0kg   2분   n
# 3  비회원         0  2022-05-02 07:22  1 / 1  보통구강구조  28  여성  0cm  0kg   2분   n
# 4  비회원         0  2022-05-02 07:20  1 / 1  보통구강구조  28  여성  0cm  0kg   2분   n
#
#   1년이내스케일링 사랑니 시린니 구취 치아흔들림 흡연 탄산음료섭취 잇몸부종,통증 하루 양치질 횟수  \
# 0        y   n   y  n     n  n      n       y        2회
# 1        y   n   n  n     n  n      n       n        2회
# 2        n   n   y  n     y  n      n       y        2회
# 3        y   n   n  n     y  n      y       n        2회
# 4        y   n   n  n     y  n      y       n        2회
#
#                                추천결과
# 0  클린디 초극세모 칫솔 / 클린디 달짝 치약 100g 시린이
# 1    클린디 기능모 칫솔 / 클린디 살짝 치약 100g 잇몸
# 2  클린디 초극세모 칫솔 / 클린디 달짝 치약 100g 시린이
# 3     클린디 미세모 칫솔 / 클린디 반짝 치약 90g 미백
# 4  클린디 미세모 칫솔 / 클린디 활짝 치약 100g 충치예방

# %%
df.dtypes
# Out:
# 구분           object
# 아이디or이메일      int64
# 진단일자         object
# 회차           object
# 악궁구조         object
# 나이            int64
# 성별           object
# 키            object
# 몸무게          object
# 양치시간         object
# 비뚠니          object
# 1년이내스케일링     object
# 사랑니          object
# 시린니          object
# 구취           object
# 치아흔들림        object
# 흡연           object
# 탄산음료섭취       object
# 잇몸부종,통증      object
# 하루 양치질 횟수    object
# 추천결과         object
# 양치시간(분)      object
# dtype: object

# %% [markdown]
# # 데이터 전처리

# %% [markdown]
# 1. 비식별화 이후 정보없음 -> 삭제
# '아이디or이메일'
#
#
# 2. datetime으로 변환
# '진단일자'
#
#
# 3. 범주형변수라서 원핫인코딩
# '구분'
# '성별'
# '악궁구조'
# '비뚠니'
# '1년이내스케일링'
# '사랑니'
# '시린니'
# '구취'
# '치아흔들림'
# '흡연'
# '탄산음료섭취'
# '잇몸부종,통증'
#
#
# 4. 단위제거
# '하루 양치질 횟수'
# '양치시간'
# '키'
# '몸무게'
#
#
# 5. tidy data로 변환
# '추천결과'

# %%
df.columns
# Out:
# Index(['구분', '아이디or이메일', '진단일자', '회차', '악궁구조', '나이', '성별', '키', '몸무게', '비뚠니',
#        '1년이내스케일링', '사랑니', '시린니', '구취', '치아흔들림', '흡연', '탄산음료섭취', '잇몸부종,통증',
#        '하루 양치질 횟수', '추천결과', '양치시간(분)'],
#       dtype='object')

# %%
# 양치시간 전처리
df['양치시간(분)'] = df['양치시간'].str.get(i=0)
df = df.drop(columns = ['양치시간'])
df.head()
# Out:
#     구분  아이디or이메일              진단일자     회차    악궁구조  나이  성별    키  몸무게 비뚠니  \
# 0  비회원         0  2022-05-02 10:19  1 / 1  보통구강구조  22  남성  0cm  0kg   n
# 1  비회원         0  2022-05-02 10:06  1 / 1  보통구강구조  22  남성  0cm  0kg   n
# 2  비회원         0  2022-05-02 09:16  1 / 1  보통구강구조  33  여성  0cm  0kg   n
# 3  비회원         0  2022-05-02 07:22  1 / 1  보통구강구조  28  여성  0cm  0kg   n
# 4  비회원         0  2022-05-02 07:20  1 / 1  보통구강구조  28  여성  0cm  0kg   n
#
#   1년이내스케일링 사랑니 시린니 구취 치아흔들림 흡연 탄산음료섭취 잇몸부종,통증 하루 양치질 횟수  \
# 0        y   n   y  n     n  n      n       y        2회
# 1        y   n   n  n     n  n      n       n        2회
# 2        n   n   y  n     y  n      n       y        2회
# 3        y   n   n  n     y  n      y       n        2회
# 4        y   n   n  n     y  n      y       n        2회
#
#                                추천결과 양치시간(분)
# 0  클린디 초극세모 칫솔 / 클린디 달짝 치약 100g 시린이       2
# 1    클린디 기능모 칫솔 / 클린디 살짝 치약 100g 잇몸       2
# 2  클린디 초극세모 칫솔 / 클린디 달짝 치약 100g 시린이       2
# 3     클린디 미세모 칫솔 / 클린디 반짝 치약 90g 미백       2
# 4  클린디 미세모 칫솔 / 클린디 활짝 치약 100g 충치예방       2

# %%
#원핫인코딩
df = df.replace('y',1)
df = df.replace('n',0)
df.head(5)
# Out:
#     구분  아이디or이메일              진단일자     회차    악궁구조  나이  성별    키  몸무게 양치시간  ...  \
# 0  비회원         0  2022-05-02 10:19  1 / 1  보통구강구조  22  남성  0cm  0kg   2분  ...
# 1  비회원         0  2022-05-02 10:06  1 / 1  보통구강구조  22  남성  0cm  0kg   2분  ...
# 2  비회원         0  2022-05-02 09:16  1 / 1  보통구강구조  33  여성  0cm  0kg   2분  ...
# 3  비회원         0  2022-05-02 07:22  1 / 1  보통구강구조  28  여성  0cm  0kg   2분  ...
# 4  비회원         0  2022-05-02 07:20  1 / 1  보통구강구조  28  여성  0cm  0kg   2분  ...
#
#    시린니  구취  치아흔들림  흡연  탄산음료섭취  잇몸부종,통증  하루 양치질 횟수  \
# 0    1   0      0   0       0        1         2회
# 1    0   0      0   0       0        0         2회
# 2    1   0      1   0       0        1         2회
# 3    0   0      1   0       1        0         2회
# 4    0   0      1   0       1        0         2회
#
#                                추천결과  양치시간(분) 나쁜습관
# 0  클린디 초극세모 칫솔 / 클린디 달짝 치약 100g 시린이        2
# 1    클린디 기능모 칫솔 / 클린디 살짝 치약 100g 잇몸        2
# 2  클린디 초극세모 칫솔 / 클린디 달짝 치약 100g 시린이        2
# 3     클린디 미세모 칫솔 / 클린디 반짝 치약 90g 미백        2
# 4  클린디 미세모 칫솔 / 클린디 활짝 치약 100g 충치예방        2
#
# [5 rows x 23 columns]

# %%
def habit(df):
    
    bad = 0

    if df['흡연'] == 'y':
        bad = += 1
        
    if df['탄산음료섭취'] =='y':
        bad = += 1
        
    if df['양치시간(분)'] <= 1:
        bad = += 1
    
    return bad

    df['나쁜습관'] =  ''
    
habit(df)
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21788/1834470093.py in <module>
#      15
#      16
# ---> 17 habit(df)
#      18 df.head(5)
#      19
#
# ~\AppData\Local\Temp/ipykernel_21788/1834470093.py in habit(df)
#       3     df['나쁜습관'] =  ''
#       4
# ----> 5     if df['흡연'] == 'y':
#       6         df['나쁜습관'] += 1
#       7
#
# ~\anaconda2\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
